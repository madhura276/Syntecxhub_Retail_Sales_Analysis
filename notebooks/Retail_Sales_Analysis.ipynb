# %%
# !pip install pandas matplotlib seaborn openpyxl jupyter
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp310-cp310-win_amd64.whl.metadata (52 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting openpyxl
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting jupyter
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\gundluru madhura\tf-env\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\gundluru madhura\tf-env\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp310-cp310-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp310-cp310-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\gundluru madhura\tf-env\lib\site-packages (from matplotlib) (11.3.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: notebook in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter) (7.4.5)
# Collecting jupyter-console (from jupyter)
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nbconvert in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter) (6.30.1)
# Collecting ipywidgets (from jupyter)
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: jupyterlab in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter) (4.4.7)
# Requirement already satisfied: six>=1.5 in c:\users\gundluru madhura\tf-env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipykernel->jupyter) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipykernel->jupyter) (8.37.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipykernel->jupyter) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipykernel->jupyter) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipykernel->jupyter) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: colorama in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: decorator in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\gundluru madhura\tf-env\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\gundluru madhura\tf-env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (311)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->jupyter)
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->jupyter)
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyterlab->jupyter) (65.5.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyterlab->jupyter) (2.2.1)
# Requirement already satisfied: anyio in c:\users\gundluru madhura\tf-env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.10.0)
# Requirement already satisfied: certifi in c:\users\gundluru madhura\tf-env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\gundluru madhura\tf-env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in c:\users\gundluru madhura\tf-env\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\gundluru madhura\tf-env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.25.1)
# Requirement already satisfied: requests>=2.31 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\gundluru madhura\tf-env\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\gundluru madhura\tf-env\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.27.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\gundluru madhura\tf-env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\gundluru madhura\tf-env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\gundluru madhura\tf-env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\gundluru madhura\tf-env\lib\site-packages (from nbconvert->jupyter) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\gundluru madhura\tf-env\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\gundluru madhura\tf-env\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\gundluru madhura\tf-env\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\gundluru madhura\tf-env\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\gundluru madhura\tf-env\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\gundluru madhura\tf-env\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\gundluru madhura\tf-env\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\gundluru madhura\tf-env\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\gundluru madhura\tf-env\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.2.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\gundluru madhura\tf-env\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\gundluru madhura\tf-env\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.23)
# Requirement already satisfied: soupsieve>1.2 in c:\users\gundluru madhura\tf-env\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\gundluru madhura\tf-env\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20250822)
# Requirement already satisfied: executing>=1.2.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\gundluru madhura\tf-env\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\gundluru madhura\tf-env\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Downloading pandas-2.3.3-cp310-cp310-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.3 MB 1.4 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/11.3 MB 1.5 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/11.3 MB 1.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.3/11.3 MB 1.3 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.6/11.3 MB 1.3 MB/s eta 0:00:08
#    ------- -------------------------------- 2.1/11.3 MB 1.5 MB/s eta 0:00:07
#    -------- ------------------------------- 2.4/11.3 MB 1.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.3 MB 1.6 MB/s eta 0:00:06
#    ------------ --------------------------- 3.4/11.3 MB 1.7 MB/s eta 0:00:05
#    ------------- -------------------------- 3.9/11.3 MB 1.7 MB/s eta 0:00:05
#    -------------- ------------------------- 4.2/11.3 MB 1.7 MB/s eta 0:00:05
#    --------------- ------------------------ 4.5/11.3 MB 1.7 MB/s eta 0:00:05
#    ---------------- ----------------------- 4.7/11.3 MB 1.7 MB/s eta 0:00:04
#    ------------------ --------------------- 5.2/11.3 MB 1.7 MB/s eta 0:00:04
#    ------------------ --------------------- 5.2/11.3 MB 1.7 MB/s eta 0:00:04
#    ------------------- -------------------- 5.5/11.3 MB 1.6 MB/s eta 0:00:04
#    -------------------- ------------------- 5.8/11.3 MB 1.6 MB/s eta 0:00:04
#    --------------------- ------------------ 6.0/11.3 MB 1.6 MB/s eta 0:00:04
#    ----------------------- ---------------- 6.6/11.3 MB 1.6 MB/s eta 0:00:04
#    ------------------------ --------------- 6.8/11.3 MB 1.6 MB/s eta 0:00:03
#    ------------------------ --------------- 7.1/11.3 MB 1.6 MB/s eta 0:00:03
#    -------------------------- ------------- 7.6/11.3 MB 1.6 MB/s eta 0:00:03
#    --------------------------- ------------ 7.9/11.3 MB 1.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 8.1/11.3 MB 1.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.4/11.3 MB 1.6 MB/s eta 0:00:02
#    ------------------------------- -------- 8.9/11.3 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 9.2/11.3 MB 1.6 MB/s eta 0:00:02
#    --------------------------------- ------ 9.4/11.3 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 10.0/11.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 10.7/11.3 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 1.5 MB/s  0:00:07
# Downloading matplotlib-3.10.9-cp310-cp310-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.2 MB 1.1 MB/s eta 0:00:07
#    -- ------------------------------------- 0.5/8.2 MB 1.1 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.0/8.2 MB 1.1 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.0/8.2 MB 1.1 MB/s eta 0:00:07
#    ------- -------------------------------- 1.6/8.2 MB 1.2 MB/s eta 0:00:06
#    -------- ------------------------------- 1.8/8.2 MB 1.2 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.1/8.2 MB 1.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.4/8.2 MB 1.3 MB/s eta 0:00:05
#    --------------- ------------------------ 3.1/8.2 MB 1.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.4/8.2 MB 1.5 MB/s eta 0:00:04
#    -------------------- ------------------- 4.2/8.2 MB 1.7 MB/s eta 0:00:03
#    --------------------- ------------------ 4.5/8.2 MB 1.6 MB/s eta 0:00:03
#    ------------------------- -------------- 5.2/8.2 MB 1.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.8/8.2 MB 1.8 MB/s eta 0:00:02
#    ------------------------------ --------- 6.3/8.2 MB 1.9 MB/s eta 0:00:02
#    --------------------------------- ------ 6.8/8.2 MB 1.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.2 MB 2.0 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.2 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 2.0 MB/s  0:00:04
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp310-cp310-win_amd64.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 3.4 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.6 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 2.0 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp310-cp310-win_amd64.whl (73 kB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading pytz-2026.2-py2.py3-none-any.whl (510 kB)
# Using cached tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Using cached widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Installing collected packages: pytz, widgetsnbextension, tzdata, pyparsing, kiwisolver, jupyterlab_widgets, fonttools, et-xmlfile, cycler, contourpy, pandas, openpyxl, matplotlib, seaborn, ipywidgets, jupyter-console, jupyter
#
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    ----------------------------------------  0/17 [pytz]
#    -- -------------------------------------  1/17 [widgetsnbextension]
#    ---- -----------------------------------  2/17 [tzdata]
#    ---- -----------------------------------  2/17 [tzdata]
#    ---- -----------------------------------  2/17 [tzdata]
#    ---- -----------------------------------  2/17 [tzdata]
#    ------- --------------------------------  3/17 [pyparsing]
#    -------------- -------------------------  6/17 [fonttools]
#    -------------- -------------------------  6/17 [fonttools]
#    -------------- -------------------------  6/17 [fonttools]
#    -------------- -------------------------  6/17 [fonttools]
#    -------------- -------------------------  6/17 [fonttools]
#    -------------- -------------------------  6/17 [fonttools]
#    -------------- -------------------------  6/17 [fonttools]
#    -------------- -------------------------  6/17 [fonttools]
#    -------------- -------------------------  6/17 [fonttools]
#    -------------- -------------------------  6/17 [fonttools]
#    -------------- -------------------------  6/17 [fonttools]
#    ---------------- -----------------------  7/17 [et-xmlfile]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ----------------------- ---------------- 10/17 [pandas]
#    ------------------------- -------------- 11/17 [openpyxl]
#    ------------------------- -------------- 11/17 [openpyxl]
#    ------------------------- -------------- 11/17 [openpyxl]
#    ------------------------- -------------- 11/17 [openpyxl]
#    ------------------------- -------------- 11/17 [openpyxl]
#    ------------------------- -------------- 11/17 [openpyxl]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ---------------------------- ----------- 12/17 [matplotlib]
#    ------------------------------ --------- 13/17 [seaborn]
#    ------------------------------ --------- 13/17 [seaborn]
#    -------------------------------- ------- 14/17 [ipywidgets]
#    ----------------------------------- ---- 15/17 [jupyter-console]
#    ---------------------------------------- 17/17 [jupyter]
#
# Successfully installed contourpy-1.3.2 cycler-0.12.1 et-xmlfile-2.0.0 fonttools-4.63.0 ipywidgets-8.1.8 jupyter-1.1.1 jupyter-console-6.6.3 jupyterlab_widgets-3.0.16 kiwisolver-1.5.0 matplotlib-3.10.9 openpyxl-3.1.5 pandas-2.3.3 pyparsing-3.3.2 pytz-2026.2 seaborn-0.13.2 tzdata-2026.2 widgetsnbextension-4.0.15
# [notice] A new release of pip is available: 25.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

df = pd.read_csv("../data/Superstore.csv", encoding="latin1")

df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
print("Shape:", df.shape)
df.info()
print(df.isnull().sum())
print("Duplicates:", df.duplicated().sum())
# Out:
# Shape: (9994, 21)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64
# Duplicates: 0

# %%
# convert dates
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# standardize column names
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# create new useful columns
df['year'] = df['order_date'].dt.year
df['month'] = df['order_date'].dt.month
df['month_name'] = df['order_date'].dt.month_name()

# verify
df.head()
# Out:
#    row_id        order_id order_date  ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           category  sub-category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# 2  Office Supplies        Labels
# 3        Furniture        Tables
# 4  Office Supplies       Storage
#
#                                         product_name     sales quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
#
#   discount    profit  year  month  month_name
# 0     0.00   41.9136  2016     11    November
# 1     0.00  219.5820  2016     11    November
# 2     0.00    6.8714  2016      6        June
# 3     0.45 -383.0310  2015     10     October
# 4     0.20    2.5164  2015     10     October
#
# [5 rows x 24 columns]

# %%
total_sales = df['sales'].sum()
total_profit = df['profit'].sum()
average_order_value = df.groupby('order_id')['sales'].sum().mean()

print("Total Sales:", total_sales)
print("Total Profit:", total_profit)
print("Average Order Value:", average_order_value)
# Out:
# Total Sales: 2297200.8603000003
# Total Profit: 286397.0217
# Average Order Value: 458.61466566180883

# %%
category_sales = df.groupby('category')['sales'].sum().sort_values(ascending=False)
category_profit = df.groupby('category')['profit'].sum().sort_values(ascending=False)

print(category_sales)
print(category_profit)
# Out:
# category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: sales, dtype: float64
# category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: profit, dtype: float64

# %%
region_sales = df.groupby('region')['sales'].sum().sort_values(ascending=False)
region_profit = df.groupby('region')['profit'].sum().sort_values(ascending=False)

print(region_sales)
print(region_profit)
# Out:
# region
# West       725457.8245
# East       678781.2400
# Central    501239.8908
# South      391721.9050
# Name: sales, dtype: float64
# region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: profit, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=region_sales.index, y=region_sales.values)

plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")

plt.savefig("../images/sales_by_region.png", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(x=category_profit.index, y=category_profit.values)

plt.title("Profit by Category")
plt.xlabel("Category")
plt.ylabel("Profit")

plt.savefig("../images/profit_by_category.png", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x=monthly_sales.index, y=monthly_sales.values, marker='o')

plt.xticks(rotation=45)
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.savefig("../images/monthly_sales_trend.png", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=top_products.values, y=top_products.index)

plt.title("Top 10 Products by Sales")
plt.xlabel("Sales")
plt.ylabel("Product")

plt.savefig("../images/top_products.png", bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x=df['discount'], y=df['profit'])

plt.title("Discount vs Profit")
plt.xlabel("Discount")
plt.ylabel("Profit")

plt.savefig("../images/discount_vs_profit.png", bbox_inches="tight")
plt.show()
